# %% [markdown]
# # Introduction to python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\Ashulah\\Desktop\\PYTHON TUTORIAL\\car price data.csv")
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data[['Present_Price','Kms_Driven','Fuel_Type']]
# Out:
#      Present_Price  Kms_Driven Fuel_Type
# 0             5.59       27000    Petrol
# 1             9.54       43000    Diesel
# 2             9.85        6900    Petrol
# 3             4.15        5200    Petrol
# 4             6.87       42450    Diesel
# ..             ...         ...       ...
# 296          11.60       33988    Diesel
# 297           5.90       60000    Petrol
# 298          11.00       87934    Petrol
# 299          12.50        9000    Diesel
# 300           5.90        5464    Petrol
#
# [301 rows x 3 columns]

# %%
data.loc[[0,2,3],['Present_Price','Kms_Driven','Fuel_Type']]
# Out:
#    Present_Price  Kms_Driven Fuel_Type
# 0           5.59       27000    Petrol
# 2           9.85        6900    Petrol
# 3           4.15        5200    Petrol

# %%
#filtering
data.loc[data['Car_Name']=='city',:]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 251     city  2013           5.00           9.90       56701    Petrol
# 253     city  2014           7.20           9.90       48000    Diesel
# 254     city  2013           5.25           9.90       54242    Petrol
# 256     city  2016          10.25          13.60       49562    Petrol
# 257     city  2015           8.50          13.60       40324    Petrol
# 258     city  2015           8.40          13.60       25000    Petrol
# 260     city  2016           9.15          13.60       29223    Petrol
# 267     city  2016           8.35           9.40       19434    Diesel
# 269     city  2015           6.70          10.00       18828    Petrol
# 270     city  2011           4.10          10.00       69341    Petrol
# 271     city  2009           3.00          10.00       69562    Petrol
# 272     city  2015           7.50          10.00       27600    Petrol
# ...

# %%
df=data.loc[:8,['Present_Price','Kms_Driven']]
df.head()
# Out:
#    Present_Price  Kms_Driven
# 0           5.59       27000
# 1           9.54       43000
# 2           9.85        6900
# 3           4.15        5200
# 4           6.87       42450

# %%
df2=data.loc[(data['Car_Name']=='city')&(data['Fuel_Type']=='Petrol'),:]

# %%
len(df2)
# Out:
# 20

# %%
data.iloc[:,[3,4,5]]
# Out:
#      Present_Price  Kms_Driven Fuel_Type
# 0             5.59       27000    Petrol
# 1             9.54       43000    Diesel
# 2             9.85        6900    Petrol
# 3             4.15        5200    Petrol
# 4             6.87       42450    Diesel
# ..             ...         ...       ...
# 296          11.60       33988    Diesel
# 297           5.90       60000    Petrol
# 298          11.00       87934    Petrol
# 299          12.50        9000    Diesel
# 300           5.90        5464    Petrol
#
# [301 rows x 3 columns]

# %% [markdown]
# # data visualization

# %%
sns.displot(data['Present_Price'],kind="kde")
plt.show()

# %%
dtypes = pd.DataFrame({'Type': ['int8', 'uint8', 'int16', 'uint16', 'int32', 'uint32', 'int64', 'uint64'],
 'Type Code': ['u2', 'i4', 'u4', 'i8', 'u8', 'f2', 'f4 or f', 'f8 or d']
 })
dtypes
# Out:
#      Type Type Code
# 0    int8        u2
# 1   uint8        i4
# 2   int16        u4
# 3  uint16        i8
# 4   int32        u8
# 5  uint32        f2
# 6   int64   f4 or f
# 7  uint64   f8 or d

# %%
import numpy as np
# create an array with a specified data type
arr = np.array([1,2,3], dtype='f2')
print(arr)
print(arr.dtype)
arr = np.array([1+2j, 3-4j], dtype=np.complex64)
print(arr)
print(arr.dtype)
# Out:
# [1. 2. 3.]
# float16
# [1.+2.j 3.-4.j]
# complex64

# %% [markdown]
# # type of data, qualitative (categorical not mathematics, discrete in mathemathics); eg male,female
# -ordianla(nursery,primary,secondrly)
# -nominal(colors: red yelow,green),sex(f,m).
# on visualisation(barplot,pie chart)
# !ON analysis: we use freuency tables(counting accurance)
# # quantitative(niumerical) data :continous; eg height,weight
# visualization(histogram,scatter,density,etc)
# statistical summarry:
# mean,standard deviation,max,min,mode,variance

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data['Fuel_Type'].unique() # to see what is unique
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
data['Fuel_Type'].value_counts().plot(kind='pie')  # in this column this how diesel used in numbers
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Table

# %%
# one way table
pd.crosstab(index=data['Fuel_Type'],columns='frequency')
# Out:
# col_0      frequency
# Fuel_Type
# CNG                2
# Diesel            60
# Petrol           239

# %%
#two way table to see relationship btn two columns
pd.crosstab(index=data['Fuel_Type'],
            columns=data['Transmission']
           ).plot(kind='bar')
plt.title('Dstribution of prices by Fuel type')
# Out:
# Text(0.5, 1.0, 'Dstribution of prices by Fuel type')

# %%
pd.crosstab(index=[data['Fuel_Type'],data['Seller_Type']],columns=data['Transmission'],margins=True, margin)
# Out:
# Transmission           Automatic  Manual  All
# Fuel_Type Seller_Type
# CNG       Dealer               0       2    2
# Diesel    Dealer              11      48   59
#           Individual           1       0    1
# Petrol    Dealer              18     116  134
#           Individual          10      95  105
# All                           40     261  301

# %% [markdown]
# # relationship btn numerical and cathegorical data

# %%
pd.pivot_table(data=data,index='Fuel_Type',values='Selling_Price',aggfunc='mean')
# Out:
#            Selling_Price
# Fuel_Type
# CNG             3.100000
# Diesel         10.278500
# Petrol          3.264184

# %%
pd.pivot_table(data=data,index=['Transmission','Fuel_Type'],values=['Selling_Price','Present_Price'],aggfunc='mean',margins=True,margins_name='Total')
# Out:
#                         Present_Price  Selling_Price
# Transmission Fuel_Type
# Automatic    Diesel         30.642500      20.699167
#              Petrol          8.746786       4.586071
# Manual       CNG             6.415000       3.100000
#              Diesel         12.107500       7.673333
#              Petrol          5.163791       3.088768
# Total                        7.628472       4.661296
